# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Mini Notebook Demo

# %%
# This is a code cell:
x = np.array([1, 2, 3, 4, 5])
m = 0.5
b = 10

y = m * x + b

# show y
y
# Out:
# array([10.5, 11. , 11.5, 12. , 12.5])

# %% [markdown]
# This is a text cell. You can use markdown.
# See: https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
#
#
# insert code as verbatim
# ```python
# for ii in range(1,5):
#     print(ii)
# ````
#
# Some Math in Latex synthax:
#
# $H(z)=\frac{Y(z)}{X(z)} $

# %%
# or do some computation and display result
# x from cell 1
# y from cell 1
plt.plot(x, y, label='y')

# %%
# next computing step
y_shifted = y + 5

plt.plot(x, y, label='y')
plt.plot(x, y_shifted, label='y_shifted')

# %%
# next computing step
y_reversed = y[::-1] + 2.5 + np.array([.5, -.2, .8, 4, -1])

plt.plot(x, y, label='y')
plt.plot(x, y_shifted, label='y_shifted')
plt.plot(x, y_reversed, label='y_shifted')
